# %% [markdown]
# # EDA for the houses sold on Funda
#
# In this jupiternotebook we conduct a analysis to get a better understanding of the funda dataset with a focus on the house prices

# %% [markdown]
# # Libraries and load

# %%
# Import libraries
import numpy as np # Linear algebra
import pandas as pd # Data processing, CSV file

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt # Plotting
import researchpy as rp # General statistics

#Import datetime to calculate the difference between two dates
from datetime import datetime

# to make jupyter print all outputs, not just the last one
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

# topic modelling, terminal installation for first two lines

### python -m spacy download en_core_web_sm
### python -m spacy download nl_core_news_sm

import spacy
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF
import re

# %%
# Reading the housing dataset 
funda = pd.read_csv("funda.csv")

# Able to show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Dataset overview

# %%
# Show first and last 5 rows 
funda.head(5)
funda.tail(5)
# Out:
#                                                 link              adress  \
# 0  https://www.funda.nl/koop/verkocht/peize/huis-...     Dalkruidlaan 18
# 1  https://www.funda.nl/koop/verkocht/ooltgenspla...   Weesmolenstraat 6
# 2  https://www.funda.nl/koop/verkocht/almere/huis...       Keiwierde 151
# 3  https://www.funda.nl/koop/verkocht/lochem/huis...     Zutphenseweg 10
# 4  https://www.funda.nl/koop/verkocht/maurik/huis...  Homoetsestraat 1 A
#
#             postcodeCity postcode                                  city  \
# 0          9321 LN Peize  9321 LN                           Peize,Peize
# 1  3257 XM Ooltgensplaat  3257 XM  Ooltgensplaat,Ooltgensplaat,woonkern
# 2         1353 NW Almere  1353 NW                     Almere,De,Wierden
# 3         7241 KR Lochem  7241 KR                      Lochem,Zuiderenk
# 4         4021 HG Maurik  4021 HG                         Maurik,Maurik
#
#   house_size plot_size  bedrooms           price     Offered_since  \
# 0     125 m²    266 m²       4.0  € 445.000 k.k.   3 december 2021
# 1      98 m²    320 m²       3.0  € 450.000 k.k.  23 november 2021
# 2      98 m²    183 m²       2.0  € 350.000 k.k.  22 november 2021
# 3     177 m²    405 m²       4.0  € 400.000 k.k.  24 november 2021
# 4     174 m²    554 m²       5.0  € 635.000 k.k.  24 november 2021
#
#        Selling_date Duration  \
# 0  10 december 2021  7 dagen
# 1  10 december 2021  2 weken
# 2  10 december 2021  2 weken
# 3  10 december 2021  2 weken
# 4  10 december 2021  2 weken
#
#                                    house_description price_sqm    status  \
# 0  Duurzaam wonen in een mooi vormgegeven 2-1 kap...   € 3.560  Verkocht
# 1  Mooie vrijstaande woning, met garage, nabij he...   € 4.592  Verkocht
# 2  Deze verrassend ruime woning gelegen aan het w...   € 3.571  Verkocht
# 3  Zutphenseweg 10, Lochem Wonen in een karakteri...   € 2.260  Verkocht
# 4  WAUW! Wat een ruimte en wat een prachtige en m...   € 3.649  Verkocht
#
#                               housetype      built_type year_of_construction  \
# 0  Eengezinswoning, 2-onder-1-kapwoning  Bestaande bouw                 2013
# 1   Eengezinswoning, vrijstaande woning  Bestaande bouw                 2006
# 2         Eengezinswoning, tussenwoning  Bestaande bouw            1981-1990
# 3  Eengezinswoning, 2-onder-1-kapwoning  Bestaande bouw            1906-1930
# 4   Eengezinswoning, vrijstaande woning  Bestaande bouw                 1999
#
#                             roof_type             NumberOfRooms  \
# 0            Gedeeltelijk gestoffeerd  5 kamers (4 slaapkamers)
# 1          Zadeldak bedekt met pannen  4 kamers (3 slaapkamers)
# 2                            Zadeldak  3 kamers (2 slaapkamers)
# 3  Samengesteld dak bedekt met pannen  5 kamers (4 slaapkamers)
# 4          Zadeldak bedekt met pannen  6 kamers (5 slaapkamers)
#
#                   NumberOfBathrooms                           NumberOfFloors  \
# 0      1 badkamer en 1 apart toilet                              3 woonlagen
# 1      1 badkamer en 1 apart toilet                              2 woonlagen
# 2      1 badkamer en 1 apart toilet              2 woonlagen en een vliering
# 3     2 badkamers en 1 apart toilet  2 woonlagen, een vliering en een kelder
# 4  1 badkamer en 2 aparte toiletten                3 woonlagen en een kelder
#
#                                           facilities energylabel  \
# 0  Balansventilatie, buitenzonwering, glasvezelka...           A
# 1  Buitenzonwering, mechanische ventilatie, TV ka...           A
# 2  Buitenzonwering, mechanische ventilatie en roo...           C
# 3                         Buitenzonwering en dakraam           C
# 4  Dakraam, mechanische ventilatie, rookkanaal en...           B
#
#                               isolation  \
# 0  Eengezinswoning, 2-onder-1-kapwoning
# 1   Eengezinswoning, vrijstaande woning
# 2         Eengezinswoning, tussenwoning
# 3  Eengezinswoning, 2-onder-1-kapwoning
# 4   Eengezinswoning, vrijstaande woning
#
#                                              heating  \
# 0  Gehele vloerverwarming, warmte terugwininstall...
# 1          Cv-ketel en gedeeltelijke vloerverwarming
# 2                                           Cv-ketel
# 3          Cv-ketel en gedeeltelijke vloerverwarming
# 4  Cv-ketel, gashaard en gedeeltelijke vloerverwa...
#
#                                             CV_ketel  \
# 0                                                NaN
# 1  Intergas (gas gestookt combiketel uit 2006, ei...
# 2           Atag (gas gestookt combiketel, eigendom)
# 3  Daalderop (gas gestookt combiketel uit 2007, e...
# 4  Nefit (gas gestookt combiketel uit 2000, eigen...
#
#                             garden  \
# 0           Achtertuin en voortuin
# 1  Achtertuin, voortuin en zijtuin
# 2           Achtertuin en voortuin
# 3           Achtertuin en voortuin
# 4            Achtertuin en zijtuin
#
#                                       gardenLocation  \
# 0                     Aan rustige weg en in woonwijk
# 1                                    Aan rustige weg
# 2  Aan rustige weg, aan water, in woonwijk en vri...
# 3                    Aan drukke weg en vrij uitzicht
# 4                                        In woonwijk
#
#                  storageSpace storageFacilities                parkingType  \
# 0   Aangebouwde stenen garage            1 auto          Openbaar parkeren
# 1  Vrijstaande houten berging               NaN  Aangebouwde stenen garage
# 2  Vrijstaande stenen berging           Elektra              Parkeerplaats
# 3  Vrijstaande houten berging               NaN  Vrijstaande stenen garage
# 4   Aangebouwde stenen garage          3 auto's           Op eigen terrein
#
#                     makelaar  amountOfImages  \
# 0  Mijn Makelaar Noordenveld            32.0
# 1     Van Rossum Makelaardij            35.0
# 2   AVENUE ´T GOOI MAKELAARS            27.0
# 3     MakelaardijDesk Lochem            54.0
# 4         Betuwe Makelaardij            35.0
#
#                                           Frontimage
# 0  https://cloud.funda.nl/valentina_media/152/570...
# 1  https://cloud.funda.nl/valentina_media/152/147...
# 2  https://cloud.funda.nl/valentina_media/152/141...
# 3  https://cloud.funda.nl/valentina_media/152/191...
# 4  https://cloud.funda.nl/valentina_media/152/203...
#                                                     link  \
# 61730  https://www.funda.nl/koop/verkocht/voorburg/ap...
# 61731  https://www.funda.nl/koop/verkocht/woubrugge/h...
# 61732  https://www.funda.nl/koop/verkocht/blokker/hui...
# 61733  https://www.funda.nl/koop/verkocht/lisse/huis-...
# 61734  https://www.funda.nl/koop/verkocht/voorthuizen...
#
#                        adress         postcodeCity postcode  \
# 61730  van Wassenaerstraat 48     2274 RD Voorburg  2274 RD
# 61731           Comriekade 23    2481 AD Woubrugge  2481 AD
# 61732       Kolenbergstraat 2      1695 CD Blokker  1695 CD
# 61733          Trompstraat 22        2161 VC Lisse  2161 VC
# 61734     Frans Halsstraat 69  3781 EV Voorthuizen  3781 EV
#
#                                 city house_size plot_size  bedrooms  \
# 61730  Voorburg,Voorburg,Noord,noord      77 m²         1       NaN
# 61731            Woubrugge,Woubrugge      95 m²    120 m²       3.0
# 61732  Blokker,Blokker,-,Buurt,31,04     104 m²    174 m²       3.0
# 61733           Lisse,Zeeheldenbuurt      84 m²    148 m²       5.0
# 61734           Voorthuizen,De,Wheem     154 m²    348 m²       4.0
#
#                 price  Offered_since     Selling_date  Duration  \
# 61730  € 299.000 k.k.    20 mei 2021      5 juni 2021   2 weken
# 61731  € 425.000 k.k.   14 juli 2021  5 augustus 2021   3 weken
# 61732  € 325.000 k.k.  16 april 2021     10 juni 2021   7 weken
# 61733  € 325.000 k.k.    1 juli 2021     15 juli 2021  14 dagen
# 61734  € 469.000 k.k.   17 juni 2021     28 juni 2021  11 dagen
#
#                                        house_description price_sqm    status  \
# 61730  Op de bovenste woonlaag gelegen (geen bovenbur...   € 3.883  Verkocht
# 61731  Vrijstaande woning gelegen aan de ‘Woudweterin...   € 4.474  Verkocht
# 61732  Let op: het betreft een "bieden vanaf prijs" v...   € 3.125  Verkocht
# 61733  Aan de Trompstraat staat deze tussenwoning in ...   € 3.869  Verkocht
# 61734  2-ONDER-1 KAPWONING AAN RUSTIG HOFJE Aan een d...   € 3.045  Verkocht
#
#                                   housetype      built_type  \
# 61730             Bovenwoning (appartement)  Bestaande bouw
# 61731   Eengezinswoning, vrijstaande woning  Bestaande bouw
# 61732           Eengezinswoning, hoekwoning  Bestaande bouw
# 61733         Eengezinswoning, tussenwoning  Bestaande bouw
# 61734  Eengezinswoning, 2-onder-1-kapwoning  Bestaande bouw
#
#       year_of_construction                                     roof_type  \
# 61730                 1927  Plat dak bedekt met bitumineuze dakbedekking
# 61731                 1988                                           NaN
# 61732                 1983                                           NaN
# 61733                 1959                    Zadeldak bedekt met pannen
# 61734                 1972                                           NaN
#
#                   NumberOfRooms                 NumberOfBathrooms  \
# 61730   2 kamers (1 slaapkamer)      1 badkamer en 1 apart toilet
# 61731  4 kamers (3 slaapkamers)                       2 woonlagen
# 61732  4 kamers (3 slaapkamers)  1 badkamer en 2 aparte toiletten
# 61733  6 kamers (5 slaapkamers)      1 badkamer en 1 apart toilet
# 61734  5 kamers (4 slaapkamers)      1 badkamer en 1 apart toilet
#
#                     NumberOfFloors   facilities energylabel  \
# 61730                  2 woonlagen  1e woonlaag           F
# 61731                          NaN          NaN           B
# 61732  2 woonlagen en een vliering          NaN           C
# 61733                  3 woonlagen     TV kabel           E
# 61734                  3 woonlagen          NaN           D
#
#                                   isolation  \
# 61730             Bovenwoning (appartement)
# 61731   Eengezinswoning, vrijstaande woning
# 61732           Eengezinswoning, hoekwoning
# 61733         Eengezinswoning, tussenwoning
# 61734  Eengezinswoning, 2-onder-1-kapwoning
#
#                                          heating  \
# 61730                                   Cv-ketel
# 61731                                   Cv-ketel
# 61732                                   Cv-ketel
# 61733                                        NaN
# 61734  Cv-ketel en gedeeltelijke vloerverwarming
#
#                                                 CV_ketel  \
# 61730  Remeha (gas gestookt combiketel uit 2015, eige...
# 61731                                                NaN
# 61732  Nefit (gas gestookt combiketel uit 2010, eigen...
# 61733                                                NaN
# 61734                          Intergas (2018, eigendom)
#
#                        garden                  gardenLocation  \
# 61730         Balkon aanwezig  Aan rustige weg en in woonwijk
# 61731              Achtertuin                   Aan vaarwater
# 61732  Achtertuin en voortuin                     In woonwijk
# 61733  Achtertuin en voortuin       In centrum en in woonwijk
# 61734             Tuin rondom                     In woonwijk
#
#                      storageSpace storageFacilities  \
# 61730           Openbaar parkeren               NaN
# 61731  Vrijstaande houten berging               NaN
# 61732   Aangebouwde stenen garage            1 auto
# 61733  Vrijstaande stenen berging           Elektra
# 61734  Aangebouwde stenen berging               NaN
#
#                      parkingType                             makelaar  \
# 61730                         Ja                 C&D Makelaardij B.V.
# 61731          Openbaar parkeren        De Koning makelaars (ERA+NVM)
# 61732           Op eigen terrein  Boekweit | Olie Makelaars/taxateurs
# 61733          Openbaar parkeren            Chantal Lefeber Makelaars
# 61734  Aangebouwde stenen garage  Drieklomp Makelaars en Rentmeesters
#
#        amountOfImages                                         Frontimage
# 61730            32.0  https://cloud.funda.nl/valentina_media/143/590...
# 61731            31.0  https://cloud.funda.nl/valentina_media/145/775...
# 61732            31.0  https://cloud.funda.nl/valentina_media/142/312...
# 61733            43.0  https://cloud.funda.nl/valentina_media/145/237...
# 61734            45.0  https://cloud.funda.nl/valentina_media/144/676...

# %%
# show the size of the dataset
print("There are {} rows and {} columns in the dataset".format(funda.shape[0], funda.shape[1]))
# Out:
# There are 61735 rows and 35 columns in the dataset

# %%
# Get all columns with the datatypes and amount non-null
funda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61735 entries, 0 to 61734
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   link                  61735 non-null  object
#  1   adress                61735 non-null  object
#  2   postcodeCity          61735 non-null  object
#  3   postcode              61734 non-null  object
#  4   city                  61735 non-null  object
#  5   house_size            60145 non-null  object
#  6   plot_size             59448 non-null  object
#  7   bedrooms              40597 non-null  float64
#  8   price                 61735 non-null  object
#  9   Offered_since         61735 non-null  object
#  10  Selling_date          60145 non-null  object
#  11  Duration              61735 non-null  object
#  12  house_description     61735 non-null  object
#  13  price_sqm             61341 non-null  object
#  14  status                59604 non-null  object
#  15  housetype             60145 non-null  object
#  16  built_type            60282 non-null  object
#  17  year_of_construction  60145 non-null  object
#  18  roof_type             51352 non-null  object
#  19  NumberOfRooms         60145 non-null  object
#  20  NumberOfBathrooms     60145 non-null  object
#  21  NumberOfFloors        54143 non-null  object
#  22  facilities            43901 non-null  object
#  23  energylabel           61735 non-null  object
#  24  isolation             60145 non-null  object
#  25  heating               56513 non-null  object
#  26  CV_ketel              40091 non-null  object
#  27  garden                50289 non-null  object
#  28  gardenLocation        55278 non-null  object
#  29  storageSpace          56348 non-null  object
#  30  storageFacilities     32541 non-null  object
#  31  parkingType           49793 non-null  object
#  32  makelaar              61735 non-null  object
#  33  amountOfImages        59419 non-null  float64
#  34  Frontimage            58142 non-null  object
# dtypes: float64(2), object(33)
# memory usage: 16.5+ MB

# %%
# Check for NULL values 
n_nulls = funda.loc[lambda x: x.isnull().any(axis=1)].shape
print(f"There are {n_nulls[0]} rows with null values in this dataset")
funda.isna().sum().sort_values(ascending=False)
# Out:
# There are 46529 rows with null values in this dataset
# storageFacilities       29194
# CV_ketel                21644
# bedrooms                21138
# facilities              17834
# parkingType             11942
# garden                  11446
# roof_type               10383
# NumberOfFloors           7592
# gardenLocation           6457
# storageSpace             5387
# heating                  5222
# Frontimage               3593
# amountOfImages           2316
# plot_size                2287
# status                   2131
# isolation                1590
# NumberOfBathrooms        1590
# NumberOfRooms            1590
# year_of_construction     1590
# housetype                1590
# Selling_date             1590
# house_size               1590
# built_type               1453
# price_sqm                 394
# postcode                    1
# adress                      0
# energylabel                 0
# house_description           0
# Duration                    0
# Offered_since               0
# price                       0
# city                        0
# makelaar                    0
# postcodeCity                0
# link                        0
# dtype: int64

# %% [markdown]
# # Clean dataset

# %%
# make a copy of the dataset
funda_df = funda.copy()

# %%
# add columns
funda_df['nr_rooms'] = funda_df['NumberOfRooms'].str.extract('(\d+)')
funda_df['nr_bedrooms'] = funda_df['NumberOfRooms'].str.extract('\d.*?(\d+)')
funda_df['area'] = funda_df['postcode'].str[0:2]

# drop columns
funda_df.drop(columns='postcodeCity', inplace=True)
funda_df.drop(columns='storageFacilities', inplace=True)
funda_df.drop(columns='bedrooms', inplace=True)
funda_df.drop(columns='NumberOfBathrooms', inplace=True)
funda_df.drop(columns='Duration', inplace=True)
funda_df.drop(columns='NumberOfRooms', inplace=True)
funda_df.drop(columns='CV_ketel', inplace=True)
funda_df.drop(columns='facilities', inplace=True)
funda_df.drop(columns='parkingType', inplace=True)
funda_df.drop(columns='roof_type', inplace=True)
funda_df.drop(columns='NumberOfFloors', inplace=True)
funda_df.drop(columns='gardenLocation', inplace=True)
funda_df.drop(columns='storageSpace', inplace=True)
funda_df.drop(columns='heating', inplace=True)
funda_df.drop(columns='isolation', inplace=True)
funda_df.drop(columns='status', inplace=True)
funda_df.drop(columns='Frontimage', inplace=True)
funda_df.drop(columns='amountOfImages', inplace=True)

# Rename values
funda_df.rename(columns={'Offered_since': 'offered_since', 'Selling_date': 'selling_date'}, inplace=True)

# Change format of values
funda_df['house_size'] = funda_df['house_size'].str.replace('m²', '',regex=True).str.replace('.', '',regex=True)
funda_df['plot_size'] = funda_df['plot_size'].str.replace('m²', '',regex=True).str.replace('.', '',regex=True)
funda_df['price'] = funda_df['price'].str.replace('€', '',regex=True).str.replace('k.k.', '',regex=True).str.replace('.', '',regex=True).str.replace('von', '',regex=True)
funda_df['offered_since'] = funda_df['offered_since'].str.replace(' ','-')
funda_df['selling_date'] = funda_df['selling_date'].str.replace(' ','-')
funda_df['price_sqm'] = funda_df['price_sqm'].str.replace('€', '',regex=True).str.replace('k.k.', '',regex=True).str.replace('.', '',regex=True)
funda_df['year_of_construction'] = funda_df['year_of_construction'].str[-4:]
funda_df['link'] = pd.Categorical((pd.factorize(funda_df.link)[0] + 1).astype(str))

# Drop rows with verkoop bij inschrijving & prijs op aanvraag
funda_df = funda_df[funda_df.price != 'Verkoop bij inschrijving']
funda_df = funda_df[funda_df.price != 'Prijs op aanvraag']
funda_df = funda_df[funda_df.built_type != 'Verkocht']
funda_df = funda_df[funda_df.built_type != '€ 217.500 kosten koper']

#Change data type to english in order to convert the format
funda_df['offered_since'] = funda_df['offered_since'].str.replace('januari', '01').str.replace('februari', '02').str.replace('maart', '03').str.replace('april', '04').str.replace('mei', '05').str.replace('juni', '06').str.replace('juli', '07').str.replace('augustus', '08').str.replace('september', '09').str.replace('oktober', '10').str.replace('november', '11').str.replace('december', '12')
funda_df['selling_date'] = funda_df['selling_date'].str.replace('januari', '01').str.replace('februari', '02').str.replace('maart', '03').str.replace('april', '04').str.replace('mei', '05').str.replace('juni', '06').str.replace('juli', '07').str.replace('augustus', '08').str.replace('september', '09').str.replace('oktober', '10').str.replace('november', '11').str.replace('december', '12')

# Add a zero to the dates beginning with days 1-9
funda_df['selling_date'] = funda_df['selling_date'].str.zfill(10)
funda_df['offered_since'] = funda_df['offered_since'].str.zfill(10)

# Change datatype to calculate difference between days
funda_df['selling_date'] = pd.to_datetime(funda_df['selling_date'], format='%d-%m-%Y')
funda_df['offered_since'] = pd.to_datetime(funda_df['offered_since'], format='%d-%m-%Y')

# Calculate difference between offering and selling date and show results in column 'duration'
funda_df['duration_days'] = funda_df.selling_date - funda_df.offered_since

# change datatype 
funda_df = funda_df.astype({'duration_days': str}, errors='raise')

# remove the word days  
funda_df['duration_days'] = funda_df['duration_days'].str.extract('(\d+)')

# split city after the comma
funda_df['city'] = funda_df['city'].str.split(',').str.get(0)

# change housetype into more general categories
funda_df['housetype'] = funda_df['housetype'].str.split(',').str.get(0)
funda_df['housetype'] = funda_df['housetype'].str.split('(').str.get(0)
funda_df['housetype'] = funda_df['housetype'].str.rstrip()
funda_df['housetype'] = funda_df['housetype'].str.replace('Beneden + bovenwoning', 'Appartement', regex=False).str.replace('Benedenwoning', 'Appartement').str.replace('Bovenwoning', 'Appartement').str.replace('Portiekflat', 'Appartement').str.replace('Galerijflat', 'Appartement').str.replace('Tussenverdieping', 'Appartement').str.replace('Dubbel benedenhuis', 'Appartement').str.replace('Portiekwoning', 'Appartement').str.replace('Penthouse', 'Appartement')
funda_df['housetype'] = funda_df['housetype'].str.replace('Landgoed', 'Landhuis').str.replace('Herenhuis', 'Landhuis').str.replace('Villa', 'Landhuis').str.replace('Woonboerderij', 'Landhuis')
funda_df['housetype'] = funda_df['housetype'].str.replace('Maisonnette', 'Eengezinswoning')
funda_df['housetype'] = funda_df['housetype'].str.replace('Grachtenpand', 'Overig').str.replace('Studentenkamer', 'Overig').str.replace('Woonboot', 'Overig')

# change energylabel to high medium low
funda_df['energylabel'] = funda_df['energylabel'].str.replace('+', '', regex=False)
funda_df['energylabel'] = funda_df['energylabel'].str.replace('A', 'Low').str.replace('B', 'Low').str.replace('C', 'Medium').str.replace('D', 'Medium').str.replace('E', 'High').str.replace('F', 'High').str.replace('G', 'High')

# check data
funda_df.head()
# Out:
#   link              adress postcode           city house_size plot_size  \
# 0    1     Dalkruidlaan 18  9321 LN          Peize       125       266
# 1    2   Weesmolenstraat 6  3257 XM  Ooltgensplaat        98       320
# 2    3       Keiwierde 151  1353 NW         Almere        98       183
# 3    4     Zutphenseweg 10  7241 KR         Lochem       177       405
# 4    5  Homoetsestraat 1 A  4021 HG         Maurik       174       554
#
#       price offered_since selling_date  \
# 0   445000     2021-12-03   2021-12-10
# 1   450000     2021-11-23   2021-12-10
# 2   350000     2021-11-22   2021-12-10
# 3   400000     2021-11-24   2021-12-10
# 4   635000     2021-11-24   2021-12-10
#
#                                    house_description price_sqm  \
# 0  Duurzaam wonen in een mooi vormgegeven 2-1 kap...      3560
# 1  Mooie vrijstaande woning, met garage, nabij he...      4592
# 2  Deze verrassend ruime woning gelegen aan het w...      3571
# 3  Zutphenseweg 10, Lochem Wonen in een karakteri...      2260
# 4  WAUW! Wat een ruimte en wat een prachtige en m...      3649
#
#          housetype      built_type year_of_construction energylabel  \
# 0  Eengezinswoning  Bestaande bouw                 2013         Low
# 1  Eengezinswoning  Bestaande bouw                 2006         Low
# 2  Eengezinswoning  Bestaande bouw                 1990      Medium
# 3  Eengezinswoning  Bestaande bouw                 1930      Medium
# 4  Eengezinswoning  Bestaande bouw                 1999         Low
#
#                             garden                   makelaar nr_rooms  \
# 0           Achtertuin en voortuin  Mijn Makelaar Noordenveld        5
# 1  Achtertuin, voortuin en zijtuin     Van Rossum Makelaardij        4
# 2           Achtertuin en voortuin   AVENUE ´T GOOI MAKELAARS        3
# 3           Achtertuin en voortuin     MakelaardijDesk Lochem        5
# 4            Achtertuin en zijtuin         Betuwe Makelaardij        6
#
#   nr_bedrooms area duration_days
# 0           4   93             7
# 1           3   32            17
# 2           2   13            18
# 3           4   72            16
# 4           5   40            16

# %%
#Check the datatypes
funda_df.dtypes
# Out:
# link                          category
# adress                          object
# postcode                        object
# city                            object
# house_size                      object
# plot_size                       object
# price                           object
# offered_since           datetime64[ns]
# selling_date            datetime64[ns]
# house_description               object
# price_sqm                       object
# housetype                       object
# built_type                      object
# year_of_construction            object
# energylabel                     object
# garden                          object
# makelaar                        object
# nr_rooms                        object
# nr_bedrooms                     object
# area                            object
# duration_days                   object
# dtype: object

# %%
# Check for NULL values 
n_nulls = funda_df.loc[lambda x: x.isnull().any(axis=1)].shape
print(f"There are {n_nulls[0]} rows with null values in this dataset")
funda_df.isna().sum().sort_values(ascending=False)
# Out:
# There are 11393 rows with null values in this dataset
# garden                  11220
# nr_bedrooms              2440
# plot_size                2147
# duration_days            1453
# housetype                1453
# house_size               1453
# nr_rooms                 1453
# selling_date             1453
# year_of_construction     1453
# built_type               1452
# area                        1
# price_sqm                   1
# postcode                    1
# adress                      0
# house_description           0
# energylabel                 0
# offered_since               0
# makelaar                    0
# price                       0
# city                        0
# link                        0
# dtype: int64

# %%
# Check for duplicates
funda_df.drop_duplicates(subset=['link']).shape[0] == funda.shape[0]
# Out:
# False

# %%
# Drop missing values in housetype
missing_valueHT = funda_df[funda_df['housetype'].isnull()].index
funda_df = funda_df.drop(missing_valueHT, axis=0)

# Drop missing value in postcode
missing_valuePC = funda_df[funda_df['postcode'].isnull()].index
funda_df = funda_df.drop(missing_valuePC, axis=0)

# %%
# Change some datatypes into int
columns = ['price','nr_rooms', 'house_size', 'duration_days', 'year_of_construction']
for col in columns:
    funda_df[col] = funda_df[col].astype('int')

# %%
# Removing NULL Values

# Where nr_bedrooms is NULL, Get nr_rooms -1
funda_df['nr_bedrooms'].fillna(funda_df['nr_rooms'] -1, inplace=True)

# Where price_sqm is NULL, Get price devided by house_size
funda_df['price_sqm'].fillna(funda_df['price'] / funda_df['house_size'], inplace=True)

# Where plot_size is NULL, Get house_size
funda_df['plot_size'].fillna(funda_df['house_size'] , inplace=True)

# Where garden is NULL, fill in geen tuin
funda_df['garden'].fillna(('Geen garden') , inplace=True)

# %%
# check null values again after changes
funda_df.isna().sum().sort_values(ascending=False)
# Out:
# link                    0
# housetype               0
# area                    0
# nr_bedrooms             0
# nr_rooms                0
# makelaar                0
# garden                  0
# energylabel             0
# year_of_construction    0
# built_type              0
# price_sqm               0
# adress                  0
# house_description       0
# selling_date            0
# offered_since           0
# price                   0
# plot_size               0
# house_size              0
# city                    0
# postcode                0
# duration_days           0
# dtype: int64

# %%
## Log function to calculate more usefull values for price
funda_df['price_log'] = np.log(funda_df['price'])

# %%
# Change some datatypes into int
columns = ['plot_size','price_sqm','nr_bedrooms']
for col in columns:
    funda_df[col] = funda_df[col].astype('int')

# Change some datatypes into categorical
columns = ['housetype','energylabel', 'built_type']
for col in columns:
    funda_df[col] = funda_df[col].astype('category')

# %%
# change garden into more general categories
funda_df.garden = funda_df.garden.apply(lambda x: 'balkon' if 'balkon' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'balkon' if 'Balkon' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'balkon' if 'Dakterras' in x else x)

funda_df.garden = funda_df.garden.apply(lambda x: 'tuin' if 'achtertuin' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'tuin' if 'tuin' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'tuin' if 'Tuin' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'tuin' if 'patio' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'tuin' if 'Patio' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'tuin' if 'Zonneterras' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'tuin' if 'zonneterras' in x else x)

funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'Elektra' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'elektra' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'auto' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'glas' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'isolatie' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'Ja' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'Nee' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'Plaats' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'water' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'Volledig' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'Geen garden' in x else x)
funda_df.garden = funda_df.garden.apply(lambda x: 'geen tuin' if 'meter' in x else x)

# %%
# Final check dataset
funda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59575 entries, 0 to 61734
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   link                  59575 non-null  category
#  1   adress                59575 non-null  object
#  2   postcode              59575 non-null  object
#  3   city                  59575 non-null  object
#  4   house_size            59575 non-null  int32
#  5   plot_size             59575 non-null  int32
#  6   price                 59575 non-null  int32
#  7   offered_since         59575 non-null  datetime64[ns]
#  8   selling_date          59575 non-null  datetime64[ns]
#  9   house_description     59575 non-null  object
#  10  price_sqm             59575 non-null  int32
#  11  housetype             59575 non-null  category
#  12  built_type            59575 non-null  category
#  13  year_of_construction  59575 non-null  int32
#  14  energylabel           59575 non-null  category
#  15  garden                59575 non-null  object
#  16  makelaar              59575 non-null  object
#  17  nr_rooms              59575 non-null  int32
#  18  nr_bedrooms           59575 non-null  int32
#  19  area                  59575 non-null  object
#  20  duration_days         59575 non-null  int32
#  21  price_log             59575 non-null  float64
# dtypes: category(4), datetime64[ns](2), float64(1), int32(8), object(7)
# memory usage: 9.7+ MB

# %%
rp.codebook(funda_df['built_type'])
# Out:
# Variable: built_type    Data Type: category
#
#  Number of Obs.: 59575
#  Number of missing obs.: 0
#  Percent missing: 0.0
#  Number of unique values: 2
#
#  Data Values and Counts:
#
#          Values  Frequency
# Bestaande bouw      54723
#      Nieuwbouw       4852

# %% [markdown]
# # Visualiseren

# %%
# Get summary of the statistics
funda_df.describe()
# Out:
#          house_size      plot_size         price     price_sqm  \
# count  59575.000000   59575.000000  5.957500e+04  59575.000000
# mean     118.752446     369.967990  4.144251e+05   3551.964918
# std       50.173636    2050.909438  2.555543e+05   1342.023127
# min       12.000000       1.000000  3.500000e+04    265.000000
# 25%       88.000000       3.000000  2.750000e+05   2679.000000
# 50%      112.000000     146.000000  3.500000e+05   3289.000000
# 75%      137.000000     266.000000  4.772500e+05   4110.000000
# max     1580.000000  283320.000000  1.575000e+07  27193.000000
#
#        year_of_construction      nr_rooms   nr_bedrooms  duration_days  \
# count          59575.000000  59575.000000  59575.000000   59575.000000
# mean            1972.961494      4.592614      3.144843      40.059874
# std               37.432298      1.584351      1.179860      79.975151
# min             1005.000000      1.000000      0.000000       0.000000
# 25%             1956.000000      4.000000      2.000000      17.000000
# 50%             1977.000000      5.000000      3.000000      22.000000
# 75%             2000.000000      5.000000      4.000000      34.000000
# max             2024.000000     37.000000      9.000000    5106.000000
#
#           price_log
# count  59575.000000
# mean      12.819264
# std        0.453697
# min       10.463103
# 25%       12.524526
# 50%       12.765688
# 75%       13.075796
# max       16.572351

# %%
#Histogram for the logaritmic function of price
sns.histplot(funda_df['price'], bins=50, color='blue', kde=True)
plt.show()
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
#Histogram for the logaritmic function of price_log
sns.histplot(funda_df['price_log'], bins=50, color='blue', kde=True)
plt.show()
# Out:
# <AxesSubplot:xlabel='price_log', ylabel='Count'>

# %%
#This for-loop looks for the outliers in the data
all_columns         = list(funda_df)
numeric_columns     = ['price', 'house_size', 'plot_size', 'price_sqm', 'year_of_construction', 'nr_rooms', 'nr_bedrooms', 'duration_days', 'price_log']
categorical_columns = [x for x in all_columns if x not in numeric_columns ]

def outlier_detect(funda_df):
    for i in funda_df.describe().columns:
        Q1=funda_df.describe().at['25%',i]
        Q3=funda_df.describe().at['75%',i]
        IQR=Q3 - Q1
        LTV=Q1 - 1.5 * IQR
        UTV=Q3 + 1.5 * IQR
        x=np.array(funda_df[i])
        p=[]

        for j in x:
            if j < LTV or j>UTV:
               p.append(j)
        print('\n Outliers for Column:', i, ' Outliers count ', len(p))


x=funda_df[numeric_columns]

outlier_detect(x)
# Out:
#  Outliers for Column: price  Outliers count  3629
#
#  Outliers for Column: house_size  Outliers count  2489
#
#  Outliers for Column: plot_size  Outliers count  4592
#
#  Outliers for Column: price_sqm  Outliers count  2651
#
#  Outliers for Column: year_of_construction  Outliers count  830
#
#  Outliers for Column: nr_rooms  Outliers count  8964
#
#  Outliers for Column: nr_bedrooms  Outliers count  26
#
#  Outliers for Column: duration_days  Outliers count  7705
#
#  Outliers for Column: price_log  Outliers count  1399

# %%
#Check the boxplots to get a better understanding of the spread
fig, axes = plt.subplots(figsize=(18, 20), nrows=4, ncols=1)

sns.boxplot(funda_df.price, ax=axes[0])
axes[1].set_title("Total price - Boxplot")
axes[1].set_xlabel('Price')

sns.boxplot(funda_df.plot_size, ax=axes[1])
axes[1].set_title("Plot size - Boxplot")
axes[1].set_xlabel('Plot size')

sns.boxplot(funda_df.house_size, ax=axes[2])
axes[1].set_title("House size - Boxplot")
axes[1].set_xlabel('House size')

sns.boxplot(funda_df.price_sqm, ax=axes[3])
axes[1].set_title("Price per square meter - Boxplot")
axes[1].set_xlabel('Price per square meter')

plt.show()
# Out:
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>
# Text(0.5, 1.0, 'Total price - Boxplot')
# Text(0.5, 0, 'Price')
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Total price - Boxplot'}, xlabel='plot_size'>
# Text(0.5, 1.0, 'Plot size - Boxplot')
# Text(0.5, 0, 'Plot size')
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='house_size'>
# Text(0.5, 1.0, 'House size - Boxplot')
# Text(0.5, 0, 'House size')
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_sqm'>
# Text(0.5, 1.0, 'Price per square meter - Boxplot')
# Text(0.5, 0, 'Price per square meter')

# %%
#remove outliers for multiple values

#Price
#find IQR
percentile25_p = funda_df['price'].quantile(0.25)
percentile75_p = funda_df['price'].quantile(0.75)
iqr_p=percentile75_p-percentile25_p
#find limits
upper_limit_p = percentile75_p + 1.5 * iqr_p
lower_limit_p = percentile25_p - 1.5 * iqr_p
#trim outliers
funda_df = funda_df[funda_df['price'] < upper_limit_p]
funda_df = funda_df[funda_df['price'] > lower_limit_p]

#Duration in days
#find IQR
percentile25 = funda_df['duration_days'].quantile(0.25)
percentile75 = funda_df['duration_days'].quantile(0.75)
iqr=percentile75-percentile25
#find limits
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
#trim outliers
funda_df = funda_df[funda_df['duration_days'] < upper_limit]
funda_df = funda_df[funda_df['duration_days'] > lower_limit]

#plot size
#find IQR
percentile25_pl = funda_df['plot_size'].quantile(0.25)
percentile75_pl = funda_df['plot_size'].quantile(0.75)
iqr_pl=percentile75_pl-percentile25_pl
#find limits
upper_limit_pl = percentile75_pl + 1.5 * iqr_pl
lower_limit_pl = percentile25_pl - 1.5 * iqr_pl
#trim outliers
funda_df = funda_df[funda_df['plot_size'] < upper_limit_pl]
funda_df = funda_df[funda_df['plot_size'] > lower_limit_pl]

#house size
#find IQR
percentile25_h = funda_df['house_size'].quantile(0.25)
percentile75_h = funda_df['house_size'].quantile(0.75)
iqr_h=percentile75_h-percentile25_h
#find limits
upper_limit_h = percentile75_h + 1.5 * iqr_h
lower_limit_h = percentile25_h - 1.5 * iqr_h
#trim outliers
funda_df = funda_df[funda_df['house_size'] < upper_limit_h]
funda_df = funda_df[funda_df['house_size'] > lower_limit_h]

#price per square meter
#find IQR
percentile25_ps = funda_df['price_sqm'].quantile(0.25)
percentile75_ps = funda_df['price_sqm'].quantile(0.75)
iqr_ps=percentile75_ps-percentile25_ps
#find limits
upper_limit_ps = percentile75_ps + 1.5 * iqr_ps
lower_limit_ps = percentile25_ps - 1.5 * iqr_ps
#trim outliers
funda_df = funda_df[funda_df['price_sqm'] < upper_limit_ps]
funda_df = funda_df[funda_df['price_sqm'] > lower_limit_ps]

# %%
#Check the boxplot of the price to get a better understanding of the spread
fig, axes = plt.subplots(figsize=(18, 20), nrows=4, ncols=1)

sns.boxplot(funda_df.price, ax=axes[0])
axes[1].set_title("Total price - Boxplot")
axes[1].set_xlabel('Price')

sns.boxplot(funda_df.plot_size, ax=axes[1])
axes[1].set_title("Plot size - Boxplot")
axes[1].set_xlabel('Plot size')

sns.boxplot(funda_df.house_size, ax=axes[2])
axes[1].set_title("House size - Boxplot")
axes[1].set_xlabel('House size')

sns.boxplot(funda_df.price_sqm, ax=axes[3])
axes[1].set_title("Price per square meter - Boxplot")
axes[1].set_xlabel('Price per square meter')

plt.show()
# Out:
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>
# Text(0.5, 1.0, 'Total price - Boxplot')
# Text(0.5, 0, 'Price')
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Total price - Boxplot'}, xlabel='plot_size'>
# Text(0.5, 1.0, 'Plot size - Boxplot')
# Text(0.5, 0, 'Plot size')
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='house_size'>
# Text(0.5, 1.0, 'House size - Boxplot')
# Text(0.5, 0, 'House size')
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_sqm'>
# Text(0.5, 1.0, 'Price per square meter - Boxplot')
# Text(0.5, 0, 'Price per square meter')

# %%
funda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43414 entries, 0 to 61734
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   link                  43414 non-null  category
#  1   adress                43414 non-null  object
#  2   postcode              43414 non-null  object
#  3   city                  43414 non-null  object
#  4   house_size            43414 non-null  int32
#  5   plot_size             43414 non-null  int32
#  6   price                 43414 non-null  int32
#  7   offered_since         43414 non-null  datetime64[ns]
#  8   selling_date          43414 non-null  datetime64[ns]
#  9   house_description     43414 non-null  object
#  10  price_sqm             43414 non-null  int32
#  11  housetype             43414 non-null  category
#  12  built_type            43414 non-null  category
#  13  year_of_construction  43414 non-null  int32
#  14  energylabel           43414 non-null  category
#  15  garden                43414 non-null  object
#  16  makelaar              43414 non-null  object
#  17  nr_rooms              43414 non-null  int32
#  18  nr_bedrooms           43414 non-null  int32
#  19  area                  43414 non-null  object
#  20  duration_days         43414 non-null  int32
#  21  price_log             43414 non-null  float64
# dtypes: category(4), datetime64[ns](2), float64(1), int32(8), object(7)
# memory usage: 7.7+ MB

# %%
# Density Plot and Histogram of the prices
sns.distplot(funda_df['price'], hist=True, kde=True, 
             bins=int(10/1), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
# Density Plot and Histogram of the prices
sns.distplot(funda_df['price_log'], hist=True, kde=True, 
             bins=int(10/1), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# C:\Users\royup\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price_log', ylabel='Density'>

# %%
# Pairplot
sns.pairplot(funda_df, y_vars=('price'))
plt.show()

# %% [markdown]
# The clearest observation in the pairplot is that house price increases as house size increases, the starting price also seems to increase as the number of rooms and bedrooms increases.

# %%
#Clear display of the duration in days between the energylabels 
plt.figure(figsize=(10,6))
sns.stripplot(data=funda_df,x='energylabel',y='price',jitter=0.3)
# Out:
# <AxesSubplot:xlabel='energylabel', ylabel='price'>

# %% [markdown]
# The data shows that houses with a lower energy consumption are generally more expensive.

# %%
#Clear display of the duration in days between the energylabels 
plt.figure(figsize=(10,6))
sns.stripplot(data=funda_df,x='housetype',y='price',jitter=0.3)
# Out:
# <AxesSubplot:xlabel='housetype', ylabel='price'>

# %% [markdown]
# This plot shows the higher end family homes are more expensive than appartments, mansions have a higher starting price, bungalows are generally cheaper.

# %%
#Clear display of the duration in days between the energylabels 
plt.figure(figsize=(10,6))
sns.stripplot(data=funda_df,x='built_type',y='price',jitter=0.3)
# Out:
# <AxesSubplot:xlabel='built_type', ylabel='price'>

# %% [markdown]
# New homes are more expensive.

# %%
#Show the correlation matrix
plt.figure(figsize = (16,10))     
sns.heatmap(funda_df.corr(),annot = True)
plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# House size, price per square meter and the number of rooms and bedrooms seem to have the highest correlation with price.

# %% [markdown]
# # Topic modelling

# %%
# taking the text as a vector
text_case = funda_df['house_description'].tolist()
text = [x.lower() for x in text_case]

# %%
# loading the dutch and english spacy language packages
nlp = spacy.load('nl_core_news_sm')
nep = spacy.load('en_core_web_sm')
type(nlp)
type(nep)
# Out:
# spacy.lang.nl.Dutch
# spacy.lang.en.English

# %%
# tokenizing the house descriptions
docs = [nlp.make_doc(x) for x in text]

# %%
# after checking the dutch stopwords the english ones were printed to then add those to the stopwords list as the house descriptions are sometimes in english
stopwords = nlp.Defaults.stop_words
stopwords_english = nep.Defaults.stop_words
nlp.Defaults.stop_words |= {'well', 'whither', 'when', 'seem', 'again', 'n’t', 'm³.', 'voorzien', 'gelegen', 'v.v', 'circa', 't/m', 'around', 'is', 'm.', 'm3.', 'which', 'their', 'along', 'give', 'see', 'ligt', 'kom', 'komt', 'vindt', 'sluit', 'extra', 'betrekking', 'getekend', 'desbetreffende', 'inhoud', 'inclusief', 'belang', 'almost', 'for', "'d", 'quite', 'made', 'nowhere', 'many', 'could', 'formerly', 'me', 'she', 'so', 'her', 'namely', 'does', 'others', 'name', 'thereafter', 'there', 'regarding', 'latterly', 'former', 'bottom', 'ours', 'us', 'per', 'if', 'go', 'least', 'seeming', 'through', 'anything', 'they', 'most', 'him', 'sometimes', 'any', 'one', 'show', 'all', 'although', 'whole', 'whether', 'too', 'perhaps', 'meanwhile', 'over', 'elsewhere', 'in', 'hence', 'becoming', 'whence', 'thence', 'take', 'same', "'s", "'ve", 'ever', 'these', 'doing', 'from', 'empty', '‘ve', 'thus', 'throughout', 'thereupon', 'used', 'serious', 'alone', 'by', 'would', 'enough', 'my', 'nine', 'therein', 'becomes', 'eight', 'move', 'together', 'neither', 'may', 'call', 'fifteen', 'themselves', 'somewhere', 'wherever', 'i', 'wherein', 'sometime', 'why', 'here', "'ll", 'the', 'without', 'even', 'three', 'will', "'m", 'part', 'ten', 'else', 'whenever', 'both', 'though', 'up', '’s', 'can', 'has', 'keep', 'except', 'more', 'nevertheless', 'a', 'unless', 'were', 'last', 'across', 'either', 'of', 'often', 'few', 'say', 'top', 'are', 'seems', 'however', 'less', 'fifty', 'have', 'upon', 'everywhere', 'none', 'always', 'thru', 'mine', '‘s', '‘d', 'other', 'already', 'out', 'hereupon', 'no', 'should', 'did', 'you', 'had', 'might', 'but', 'become', 'something', 'or', 'two', 'beforehand', 'first', 'rather', 'five', 'further', 'herself', 'your', 'about', 'six', 'as', 'nobody', 'with', 'them', 'what', 'yet', '‘ll', 'onto', 'above', 'some', 'since', 'yourself', '’re', 'latter', 'towards', 'anywhere', 'therefore', 'down', 'forty', 'he', 'using', 'moreover', 'whom', 'being', "'re", 'please', 'not', 'indeed', 'who', 'until', 're', 'nothing', 'behind', 'within', 'then', 'we', 'whereas', 'into', 'to', 'than', 'below', 'nor', 'everyone', 'and', 'yourselves', 'because', 'now', 'afterwards', 'under', 'anyone', 'besides', 'put', 'hereby', '’ll', 'four', 'at', 'himself', 'amount', 'whoever', 'various', 'against', 'was', 'make', 'much', 'while', 'myself', 'an', 'ca', 'everything', 'done', 'how', 'on', '’d', 'anyway', 'still', 'off', 'front', '‘m', 'toward', 'such', 'hers', 'this', 'itself', 'side', 'before', 'whose', 'his', 'beyond', 'our', 'am', 'only', 'cannot', '’m', 'been', 'third', 'twelve', 'sixty', 'eleven', 'whereby', 'whatever', 'mostly', 'full', '‘re', 'became', 'during', 'be', 'beside', 'every', 'whereupon', 'back', 'someone', 'somehow', 'due', 'seemed', 'between', 'after', 'get', 'must', 'next', 'among', 'where', 'herein', 'ourselves', 'those', '’ve', 'just', 'own', 'anyhow', 'amongst', 'hundred', 'very', 'several', 'yours', 'whereafter', 'once', 'via', 'do', 'its', 'n‘t', "n't", 'twenty', 'that', 'another', 'it', 'thereby', 'otherwise', 'hereafter', 'noone', 'also', 'really', 'each', 'never', 'm', 'x', 'vaste', 'ii', 'i', 'ca.'}
print(nlp.Defaults.stop_words)
# Out:
# {'beide', 'anywhere', 'over', 'even', 'while', 'zoveel', 'eleven', "'m", 'a', 'fifty', 'niets', 'sinds', 'until', 'deze', 'was', 'in', 'yourself', 'gemogen', 'm.', 'meanwhile', 'nogal', 'weg', 'nine', 'more', 'kom', 'always', 'alle', 'quite', 'zelfde', 'zoals', 'within', 'vooruit', 'onder', 'daarop', 'hier', 'whatever', 'now', 'uw', 'unless', 'moet', 'iets', 'gewoon', 'became', 'yours', 'jezelf', 'ten', 'serious', 'gehad', 'ooit', 'yourselves', 'seeming', 'maar', 'zo', 'hebben', 'voordien', 'who', 'besides', 'bijvoorbeeld', 'be', 'mogen', 'wanneer', '’m', 'mag', 'few', 'when', 'former', 'de', 'call', 'three', 'des', 'evenwel', 'either', 'vooral', 'zou', 'omlaag', 'well', "'d", 'minder', 'thence', 'top', 'at', 'sometime', 'af', 'nu', 'anderzijds', 'nevertheless', 'iemand', 'waarom', 'effe', 'uitgezonderd', 'onto', 'vrij', 'which', 'tamelijk', 'aangaangde', 'something', 'het', 'vanuit', 'zelf', 'm³.', 'fifteen', 'beforehand', 'daarom', 'inmiddels', 'among', 'aangezien', 'beneden', 'if', 'get', 'zei', 'men', 'lang', 'there', 'other', 'hereupon', 'everyone', 'zulke', 'name', 'zichzelf', 'myself', 'inzake', 'much', 'less', 'geheel', '’ll', 'had', 'mochten', 'heb', 'many', 'thus', 'werd', 'enkel', 'alles', 'uwen', 'she', "'re", 'up', 'desbetreffende', 'have', 'please', 'seem', 'geweest', 'bij', 'whose', 'cannot', 'naar', 'totdat', 'uwe', 'weinige', 'its', 'krachtens', 'eersten', 'own', 'ourselves', 'enkele', 'voorbij', 'allen', 'because', 'kon', 'hereby', 'zich', 'tijdens', 'never', 'daarheen', 'circa', 'ander', 'hadden', 'omver', 'vindt', 'per', 'does', 'why', "'ll", 'elsewhere', 'ii', 'vaste', 'welken', 'is', 'you', 'voorheen', 'eight', 'n‘t', 'publ', 'across', 'under', 'ikke', 'net', 'je', 'nabij', 'klaar', 'gelegen', 'move', 'indeed', 'everything', 'bovenal', 'kunnen', 'nr', 'zijnde', 'since', 'getekend', 'also', 'really', 'allebei', 'haar', 'beside', 'zal', 'vroeg', 'though', 'boven', 'spoedig', 'their', 'perhaps', 'first', 'hoewel', 'become', 'zij', 'gegeven', 'sedert', 'mijn', 'mogelijk', 'forty', 'jou', 'daarnet', 'voorts', 'meesten', 'namely', 'echter', 'weinig', 'least', 'gekund', 'precies', 'may', 'alone', 'opzij', 'dezelfde', 'mede', 'zelfs', 'this', 'kunt', 'your', 'we', 'sommige', 'each', 'doorgaans', 'komt', 'betere', 'behalve', 'zeer', 'last', 'der', 'als', 'tegen', 'daarin', 'thereafter', 'beter', 're', 'one', 'eerder', 'weldra', 'zijn', 't/m', 'tussen', 'herein', 'above', 'op', 'thans', 'whither', 'can', 'hen', 'here', 'dan', 'sindsdien', 'ter', 'verre', 'ge', 'omdat', 'them', 'jij', 'below', 'latter', 'often', 'two', 'hence', 'therefore', 'four', 'altijd', 'from', 'liet', 'after', 'binnenin', 'tenzij', 'zeker', 'ever', 'daarna', 'mezelf', 'noone', 'inz', 'twelve', 'afgelopen', 'wezen', "'t", 'third', 'ik', 'so', 'inhoud', 'aan', '’re', 'vooralsnog', 'her', 'back', 'and', 'sometimes', 'towards', 'somewhere', 'mij', 'during', 'hebt', 'jouwe', 'wiens', 'mijzelf', 'wherever', 'betrekking', 'by', 'that', 'several', 'misschien', 'once', 'van', 'met', 'whole', 'else', '‘m', 'want', 'werden', 'go', 'vaak', 'neither', 'anyone', 'did', 'almost', 'then', 'off', 'pas', 'nog', 'elke', 'bovenstaand', 'verder', 'themselves', 'becoming', 'whereupon', 'omstreeks', 'his', 'him', 'thereupon', 'hare', 'niet', 'jullie', '‘ve', 'twenty', 'such', 'waren', 'ze', 'anderen', 'extra', 'vooraf', 'however', 'volgens', 'together', 'been', 'belang', 'except', 'between', 'die', 'zodra', 'as', 'do', 'any', 'aldus', 'ongeveer', 'moesten', 'welk', 'it', 'seemed', 'eerst', 'about', 'are', 'moreover', 'me', 'eerste', 'wilde', 'due', 'becomes', 'an', 'nadat', 'achterna', 'wat', 'put', 'den', 'nooit', 'vanwege', 'whereafter', 'veeleer', 'mostly', 'but', 'someone', 'too', 'zowat', 'just', 'een', 'er', 'give', 'etc', 'voorop', 'my', 'gedurende', 'they', "'ve", 'seems', '‘re', 'ca', 'along', 'should', 'with', 'both', 'rondom', 'those', 'doch', 'our', 'although', 'mocht', 'every', 'gij', 'dit', 'nobody', 'juist', 'x', 'used', 'whereas', 'ja', 'doen', 'onde ...

# %%
# creating a regex for use in filtering out unwanted strings, this regex should filter out numbers, punctuation and string that does not contain words
digit_re = re.compile('^([0-9]|[\W]|[\\.,])*$')
if re.match(digit_re, "bkgjh7"):
    print("it's a match")
else:
    print("it's not a match")
# Out:
# it's not a match

# %%
# cleaning the previously created tokens, this is done by removing all tokens that are: stopwords, punctuation or numbers.
tokens_cleaned = []
for doc in docs:
    new_tokens = []
    for token in doc:
        if not token.is_stop and not token.is_punct and not token.is_space and not token.is_currency and not re.match(digit_re, token.text):
            new_tokens.append(token.text) 
    tokens_cleaned.append(new_tokens)

# %%
# fitting the cleaned tokens into the frequency matrix
def dummy(doc):
    return doc

count_vectorizer = CountVectorizer(
    tokenizer=dummy,
    preprocessor=dummy,
    )

frequency_matrix = count_vectorizer.fit_transform(tokens_cleaned)

# %%
# looking at the feature names
count_vectorizer.get_feature_names_out()
# Out:
# array(["'is", "'n", "'ns", ..., '•zonnig', '•zonnige', '•zó'],
#       dtype=object)

# %%
# checking the dimensions of the matrix
frequency_matrix
# Out:
# <43414x114886 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7028393 stored elements in Compressed Sparse Row format>

# %%
# limiting the amount of features being used in the model, the Tfid transformation coming next gives a higher weight to values that appear in a certain description while not 
# appearing often in the rest of the data. Because of this random values that appear once would add noise to the model by being valued quite highly.
count_vectorizer = CountVectorizer(
    tokenizer=dummy,
    preprocessor=dummy,
    max_features=10000
    )

frequency_matrix = count_vectorizer.fit_transform(tokens_cleaned)
frequency_matrix
# Out:
# <43414x10000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6649935 stored elements in Compressed Sparse Row format>

# %%
# the Tfid transformation
tfd_idf_trans = TfidfTransformer()
tf_idf_matrix = tfd_idf_trans.fit_transform(frequency_matrix)

# %%
# we apply a NMF model to the data, deciding on a n of 10.
model = NMF(n_components=7, init='nndsvd')
model.fit(X=tf_idf_matrix)
# Out:
# NMF(init='nndsvd', n_components=7)

# %%
# fitted NMF that shows the top words that define the topic
def get_topics(model, n_top_words):
    
    feature_names = count_vectorizer.get_feature_names_out()
    d = {}
    for i in range(model.n_components):
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feature_names[key] for key in words_ids]
        d['Topic # ' + '{:02d}'.format(i+1)] = words
    return pd.DataFrame(d)

# %%
# showing the top 20 words that define the topic
get_topics(model, 20)
# Out:
#      Topic # 01            Topic # 02                Topic # 03 Topic # 04  \
# 0    verdieping           appartement            meetinstructie      floor
# 1        woning                balkon          koopovereenkomst       room
# 2    achtertuin               complex              particuliere   spacious
# 3         ruime              uitzicht                     koper      house
# 4    slaapkamer                  lift                  verkoper    located
# 5   achterzijde               berging                   nen2580  apartment
# 6        keuken                 maand                informatie    kitchen
# 7   slaapkamers                   vve                     meten     living
# 8     voorzijde               toegang                mondelinge    storage
# 9      overloop         parkeerplaats               verschillen   bathroom
# 10      berging  appartementencomplex                   bedoeld     garden
# 11           2e                entree           overeenstemming      space
# 12     badkamer             woonkamer       gebruiksoppervlakte     access
# 13      toegang                keuken                    meting   bedrooms
# 14    woonkamer              centrale  interpretatieverschillen       area
# 15         tuin                   hal                 indicatie    bedroom
# 16      moderne            afgesloten               afrondingen    balcony
# 17     achterom                 ruime            meetuitkomsten   entrance
# 18       toilet         servicekosten               beperkingen    parking
# 19           1e           trappenhuis                    manier      large
#
#              Topic # 05   Topic # 06   Topic # 07
# 0                    m²       woning       garage
# 1                    m³       ruimte        oprit
# 2                woning         tuin    bijkeuken
# 3              bouwjaar         huis       woning
# 4       woonoppervlakte        grote         tuin
# 5            verdieping     heerlijk        ruime
# 6    perceeloppervlakte         twee   verdieping
# 7            slaapkamer        fijne           m2
# 8                 groot       keuken      toegang
# 9               perceel         plek       royale
# 10              berging    woonkamer  slaapkamers
# 11               toilet  slaapkamers  vrijstaande
# 12                grond        mooie        biedt
# 13          aanvaarding      minuten  aangebouwde
# 14              externe        wonen        grond
# 15          slaapkamers   verdieping     badkamer
# 16  nvm-aankoopmakelaar     genieten       begane
# 17               totaal         vind    woonkamer
# 18               douche        licht      perceel
# 19                   1e       tweede      carport

# %%
# transforming the model to have weights
document_topics = model.transform(X=tf_idf_matrix)
document_topics.shape
# Out:
# (43414, 7)

# %%
# changing the model to a dataframe
funda_topics = pd.DataFrame(document_topics)

# %%
# resetting the index row so the row numbers match with the topic modelling dataframe
funda_df.reset_index(drop=True, inplace=True)

# %%
# combining the funda dataframe with the topic modelling scores
funda_df = pd.concat([funda_df, funda_topics], axis=1)

# %%
# checking to see if the merger was succesful
funda_df.head()
# Out:
#   link              adress postcode           city  house_size  plot_size  \
# 0    1     Dalkruidlaan 18  9321 LN          Peize         125        266
# 1    2   Weesmolenstraat 6  3257 XM  Ooltgensplaat          98        320
# 2    3       Keiwierde 151  1353 NW         Almere          98        183
# 3    4     Zutphenseweg 10  7241 KR         Lochem         177        405
# 4    5  Homoetsestraat 1 A  4021 HG         Maurik         174        554
#
#     price offered_since selling_date  \
# 0  445000    2021-12-03   2021-12-10
# 1  450000    2021-11-23   2021-12-10
# 2  350000    2021-11-22   2021-12-10
# 3  400000    2021-11-24   2021-12-10
# 4  635000    2021-11-24   2021-12-10
#
#                                    house_description  price_sqm  \
# 0  Duurzaam wonen in een mooi vormgegeven 2-1 kap...       3560
# 1  Mooie vrijstaande woning, met garage, nabij he...       4592
# 2  Deze verrassend ruime woning gelegen aan het w...       3571
# 3  Zutphenseweg 10, Lochem Wonen in een karakteri...       2260
# 4  WAUW! Wat een ruimte en wat een prachtige en m...       3649
#
#          housetype      built_type  year_of_construction energylabel garden  \
# 0  Eengezinswoning  Bestaande bouw                  2013         Low   tuin
# 1  Eengezinswoning  Bestaande bouw                  2006         Low   tuin
# 2  Eengezinswoning  Bestaande bouw                  1990      Medium   tuin
# 3  Eengezinswoning  Bestaande bouw                  1930      Medium   tuin
# 4  Eengezinswoning  Bestaande bouw                  1999         Low   tuin
#
#                     makelaar  nr_rooms  nr_bedrooms area  duration_days  \
# 0  Mijn Makelaar Noordenveld         5            4   93              7
# 1     Van Rossum Makelaardij         4            3   32             17
# 2   AVENUE ´T GOOI MAKELAARS         3            2   13             18
# 3     MakelaardijDesk Lochem         5            4   72             16
# 4         Betuwe Makelaardij         6            5   40             16
#
#    price_log         0         1         2         3         4         5  \
# 0  13.005830  0.017452  0.000000  0.000000  0.000000  0.003408  0.006839
# 1  13.017003  0.007218  0.001430  0.000000  0.000000  0.000000  0.015854
# 2  12.765688  0.019417  0.000000  0.083255  0.000524  0.000000  0.022630
# 3  12.899220  0.013943  0.005059  0.001267  0.000000  0.020889  0.007832
# 4  13.361380  0.005916  0.003539  0.000000  0.001411  0.000000  0.043611
#
#           6
# 0  0.027612
# 1  0.076030
# 2  0.000000
# 3  0.052193
# 4  0.052725

# %%
# renaming the new columns
funda_df.rename(columns={0: 'house properties', 1: 'facilities', 2: 'monetary specifications', 3: 'english description', 4: 'measureable properties', 5: 'ambiance description', 6: 'extra\'s'}, inplace=True)

# %%
# checking if renaming worked
funda_df.head()
# Out:
#   link              adress postcode           city  house_size  plot_size  \
# 0    1     Dalkruidlaan 18  9321 LN          Peize         125        266
# 1    2   Weesmolenstraat 6  3257 XM  Ooltgensplaat          98        320
# 2    3       Keiwierde 151  1353 NW         Almere          98        183
# 3    4     Zutphenseweg 10  7241 KR         Lochem         177        405
# 4    5  Homoetsestraat 1 A  4021 HG         Maurik         174        554
#
#     price offered_since selling_date  \
# 0  445000    2021-12-03   2021-12-10
# 1  450000    2021-11-23   2021-12-10
# 2  350000    2021-11-22   2021-12-10
# 3  400000    2021-11-24   2021-12-10
# 4  635000    2021-11-24   2021-12-10
#
#                                    house_description  price_sqm  \
# 0  Duurzaam wonen in een mooi vormgegeven 2-1 kap...       3560
# 1  Mooie vrijstaande woning, met garage, nabij he...       4592
# 2  Deze verrassend ruime woning gelegen aan het w...       3571
# 3  Zutphenseweg 10, Lochem Wonen in een karakteri...       2260
# 4  WAUW! Wat een ruimte en wat een prachtige en m...       3649
#
#          housetype      built_type  year_of_construction energylabel garden  \
# 0  Eengezinswoning  Bestaande bouw                  2013         Low   tuin
# 1  Eengezinswoning  Bestaande bouw                  2006         Low   tuin
# 2  Eengezinswoning  Bestaande bouw                  1990      Medium   tuin
# 3  Eengezinswoning  Bestaande bouw                  1930      Medium   tuin
# 4  Eengezinswoning  Bestaande bouw                  1999         Low   tuin
#
#                     makelaar  nr_rooms  nr_bedrooms area  duration_days  \
# 0  Mijn Makelaar Noordenveld         5            4   93              7
# 1     Van Rossum Makelaardij         4            3   32             17
# 2   AVENUE ´T GOOI MAKELAARS         3            2   13             18
# 3     MakelaardijDesk Lochem         5            4   72             16
# 4         Betuwe Makelaardij         6            5   40             16
#
#    price_log  House properties  Facilities  Monetary specifications  \
# 0  13.005830          0.017452    0.000000                 0.000000
# 1  13.017003          0.007218    0.001430                 0.000000
# 2  12.765688          0.019417    0.000000                 0.083255
# 3  12.899220          0.013943    0.005059                 0.001267
# 4  13.361380          0.005916    0.003539                 0.000000
#
#    English description  Measureable properties  Ambiance description   Extra's
# 0             0.000000                0.003408              0.006839  0.027612
# 1             0.000000                0.000000              0.015854  0.076030
# 2             0.000524                0.000000              0.022630  0.000000
# 3             0.000000                0.020889              0.007832  0.052193
# 4             0.001411                0.000000              0.043611  0.052725

# %% [markdown]
# # Creating the csv for use in modelling

# %%
# dropping unneccessary columns
funda_df.drop(columns=['adress', 'postcode', 'city', 'house_description', 'makelaar', 'offered_since', 'selling_date'], inplace=True)

# %%
# creating csv
funda_df.to_csv('houseprices.csv',index=False)
